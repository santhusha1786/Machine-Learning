# %%
#BoxPlot
import pandas as pd
data = pd.read_csv( r"D:\python_materials\ML_Class\Machine_Learning_Codes-master\Pre Processing\Topic 3 - MatPlotLib\DataSet\hrdata.csv" )
import matplotlib.pyplot as plt
data
# Out:
#       EmployeeCount  EmployeeID              Department  \
# 0                 1           1                   Sales
# 1                 1           2  Research & Development
# 2                 1           4  Research & Development
# 3                 1           5  Research & Development
# 4                 1           7  Research & Development
# ...             ...         ...                     ...
# 1465              1        2061  Research & Development
# 1466              1        2062  Research & Development
# 1467              1        2064  Research & Development
# 1468              1        2065                   Sales
# 1469              1        2068  Research & Development
#
#                         JobRole Attrition  Gender  Age MaritalStatus  \
# 0               Sales Executive       Yes  Female   41        Single
# 1            Research Scientist        No    Male   49       Married
# 2         Laboratory Technician       Yes    Male   37        Single
# ...

# %%
plt.boxplot( data['Income'] )
plt.show()

# %%
iris_data = pd.read_csv( r"D:\python_materials\ML_Class\Machine_Learning_Codes-master\Pre Processing\Topic 3 - MatPlotLib\DataSet\iris.csv" )
print( f"iris_data :- \n{ iris_data }\n" )
iris_data.plot( kind = 'box', color = 'red' )
plt.title( "Box Plot 1" )
plt.show()
# Out:
# iris_data :-
#      Sepal.Length  Sepal.Width  Petal.Length  Petal.Width    Species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]
