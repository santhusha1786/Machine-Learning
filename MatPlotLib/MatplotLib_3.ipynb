# %%
#When we work with histogram then we need to have only one data which will be x-axis data
#and y will be the freq. occurance of each element in x-axis data

import matplotlib.pyplot as plt
import random
import pandas as pd

# %%
# Syntax for Random,
# random.randrange(start_value, End_value, incrementation)
random.randrange( 20, 50, 3 ) #-> 20, 23, 26, 29, ... , 48
# Out:
# 26

# %%
roll_no = []
for i in range(1, 41):  # 1, 2, .., 39, 40
    roll_no.append( random.randrange(1, 11, 1) )
print(f"roll_no = {roll_no}\n")
# Out:
# roll_no = [9, 6, 8, 1, 8, 8, 3, 9, 3, 9, 8, 7, 5, 8, 6, 2, 6, 2, 3, 4, 1, 3, 4, 6, 8, 4, 5, 10, 5, 10, 5, 5, 8, 9, 4, 1, 2, 8, 4, 4]

# %%
plt.hist( roll_no, label = 'Roll_no V/s Count - Graph 1')
plt.xlabel('roll_no')
plt.ylabel('Occurance Freq')
plt.title( 'Histogram Graph' )
plt.legend()
plt.show()

# %%
plt.hist( roll_no, rwidth=0.9, label = 'Roll_no V/s Count - Graph 2')
plt.xlabel('roll_no')
plt.ylabel('Occurance Freq')
plt.title( 'Histogram Graph' )
plt.legend()
plt.show()

# %%
#bin is about the no of categories belong to some to some range.
#Ex :- Out of 40. 15 data are belonging from 1 to 4 range
#Ex :- Out of 40. 12 data are belonging from 4 to 7 range
#Ex :- Out of 40. 13 data are belonging from 7 to 10 range

plt.hist( roll_no, rwidth=0.9, bins = 4, label = 'Roll_no V/s Count - Graph 2')
plt.xlabel('roll_no')
plt.ylabel('Occurance Freq')
plt.title( 'Histogram Graph' )
plt.legend()
plt.show()

# %%
#If we want to give custom ranges

marks = []
for i in range( 1, 50 ):
    marks.append( random.randrange(1, 101, 10) )

print( f"marks = { marks }\n" )

# 1 to 35 -> Fail
# 36 to 60 -> Just Pass
# 61 to 70 -> Pass
# 71 to 80 -> Good
# 81 to 90 -> Very Good
# 91 to 100 -> Excellent
# Out:
# marks = [31, 81, 71, 21, 71, 21, 21, 41, 11, 21, 51, 51, 21, 81, 1, 61, 81, 51, 61, 31, 1, 51, 51, 91, 31, 11, 41, 41, 41, 21, 1, 91, 61, 81, 21, 41, 81, 61, 61, 1, 81, 61, 61, 61, 71, 71, 1, 31, 51]

# %%
plt.hist( marks, rwidth=0.9, bins = [ 1, 36, 61, 71, 81, 91, 101 ], label = 'Roll_no V/s Count - Graph 2')
plt.xlabel('Marks')
plt.ylabel('Occurance Freq')
plt.title( 'Histogram Graph - Marks Distribution' )
plt.legend()
plt.show()

# %%
#outline graph for histrogram 
plt.hist( marks  
          , rwidth=0.9
          , bins = [ 1, 36, 61, 71, 81, 91, 101 ]
          , color = 'green'
          , histtype = 'step'
          , label = 'Roll_no V/s Count - Graph 2')
plt.xlabel('Marks')
plt.ylabel('Occurance Freq')
plt.title( 'Histogram Graph - Marks Distribution' )
plt.legend()
plt.show()

# %%
#plotting Multiple data at a time
class_A_marks = marks.copy()
class_B_marks = []
for i in range( 1, 50 ):
    class_B_marks.append( random.randrange(1, 101, 10) )
print( f"class_A_marks :- \n{ class_A_marks }\n" )
print( f"class_B_marks :- \n{ class_B_marks }\n" )
plt.hist( [ class_A_marks, class_B_marks ]
          , rwidth = 0.9
          , bins = [ 1, 36, 61, 71, 81, 91, 101 ]
          , color = [ 'red', 'green' ]
          , label = ['Class A', 'Class B'] )
plt.xlabel('Class A V/s Class B')
plt.ylabel('Occurance Freq')
plt.title( 'Histogram Graph - Marks Distribution' )
plt.legend()
plt.show()
plt.hist( [ class_A_marks, class_B_marks ]
          , rwidth = 0.9
          , bins = [ 1, 36, 61, 71, 81, 91, 101 ]
          , color = [ 'red', 'green' ]
          , label = ['Class A', 'Class B']
          , orientation = 'horizontal'
          )
plt.xlabel('Class A V/s Class B')
plt.ylabel('Occurance Freq')
plt.title( 'Histogram Graph - Marks Distribution' )
plt.legend()
plt.show()
# Out:
# class_A_marks :-
# [31, 81, 71, 21, 71, 21, 21, 41, 11, 21, 51, 51, 21, 81, 1, 61, 81, 51, 61, 31, 1, 51, 51, 91, 31, 11, 41, 41, 41, 21, 1, 91, 61, 81, 21, 41, 81, 61, 61, 1, 81, 61, 61, 61, 71, 71, 1, 31, 51]
#
# class_B_marks :-
# [71, 41, 71, 11, 41, 51, 81, 31, 31, 31, 21, 31, 71, 51, 21, 61, 81, 91, 51, 31, 81, 51, 1, 21, 41, 41, 51, 31, 21, 51, 1, 71, 21, 61, 21, 61, 91, 61, 41, 1, 71, 11, 31, 81, 51, 51, 41, 91, 71]

# %%
hr_data = pd.read_csv( r"D:\python_materials\ML_Class\Machine_Learning_Codes-master\Pre Processing\Topic 3 - MatPlotLib\DataSet\hrdata.csv" )
hr_data
#reading csv formet excel data  and print
# Out:
#       EmployeeCount  EmployeeID              Department  \
# 0                 1           1                   Sales
# 1                 1           2  Research & Development
# 2                 1           4  Research & Development
# 3                 1           5  Research & Development
# 4                 1           7  Research & Development
# ...             ...         ...                     ...
# 1465              1        2061  Research & Development
# 1466              1        2062  Research & Development
# 1467              1        2064  Research & Development
# 1468              1        2065                   Sales
# 1469              1        2068  Research & Development
#
#                         JobRole Attrition  Gender  Age MaritalStatus  \
# 0               Sales Executive       Yes  Female   41        Single
# 1            Research Scientist        No    Male   49       Married
# 2         Laboratory Technician       Yes    Male   37        Single
# 3            Research Scientist        No  Female   33       Married
# 4         Laboratory Technician        No    Male   27       Married
# ...                         ...       ...     ...  ...           ...
# 1465      Laboratory Technician        No    Male   36       Married
# 1466  Healthcare Representative        No    Male   39       Married
# 1467     Manufacturing Director        No    Male   27       Married
# 1468            Sales Executive        No    Male   49       Married
# 1469      Laboratory Technician        No    Male   34       Married
#
#           Education EducationField  ... Hourlyrate Income  Salaryhike  \
# 0           College  Life Sciences  ...         94   5993          11
# 1     Below College  Life Sciences  ...         61   5130          23
# 2           College          Other  ...         92   2090          15
# 3            Master  Life Sciences  ...         56   2909          11
# 4     Below College        Medical  ...         40   3468          12
# ...             ...            ...  ...        ...    ...         ...
# 1465        College        Medical  ...         41   2571          17
# 1466  Below College        Medical  ...         42   9991          15
# 1467       Bachelor  Life Sciences  ...         87   6142          20
# 1468       Bachelor        Medical  ...         63   5390          14
# 1469       Bachelor        Medical  ...         82   4404          12
#
#      OverTime  Workex  YearsSinceLastPromotion  EmpSatisfaction  \
# 0         Yes       8                        0           Medium
# 1          No      10                        1             High
# 2         Yes       7                        0        Very High
# 3         Yes       8                        3        Very High
# 4          No       6                        2              Low
# ...       ...     ...                      ...              ...
# 1465       No      17                        0             High
# 1466       No       9                        1        Very High
# 1467      Yes       6                        0           Medium
# 1468       No      17                        0        Very High
# 1469       No       6                        1           Medium
#
#      TrainingTimesLastYear  WorkLifeBalance  Performance_Rating
# 0                        0              Bad           Excellent
# 1                        3           Better         Outstanding
# 2                        3           Better           Excellent
# 3                        3           Better           Excellent
# 4                        3           Better           Excellent
# ...                    ...              ...                 ...
# 1465                     3           Better           Excellent
# 1466                     5           Better           Excellent
# 1467                     0           Better         Outstanding
# 1468                     3             Good           Excellent
# 1469                     3             Best           Excellent
#
# [1470 rows x 24 columns]

# %%
hr_data.columns
# Out:
# Index(['EmployeeCount', 'EmployeeID', 'Department', 'JobRole', 'Attrition',
#        'Gender', 'Age', 'MaritalStatus', 'Education', 'EducationField',
#        'BusinessTravel', 'JobInvolvement', 'JobLevel', 'JobSatisfaction',
#        'Hourlyrate', 'Income', 'Salaryhike', 'OverTime', 'Workex',
#        'YearsSinceLastPromotion', 'EmpSatisfaction', 'TrainingTimesLastYear',
#        'WorkLifeBalance', 'Performance_Rating'],
#       dtype='object')

# %%
#alpha for brightnesss controll
#alpha range is from 0 to 1
plt.hist( hr_data['Income'], bins = 10, color = 'red', alpha = 0.2, label = 'alpha = 0.2' )
plt.legend()
plt.show()

# %%
plt.hist( hr_data['Income'], bins = 10, color = 'red', alpha = 0.3, label = 'alpha = 0.3' )
plt.legend()
plt.show()

# %%
plt.hist( hr_data['Income'], bins = 10, color = 'red', alpha = 0.4, label = 'alpha = 0.4' )
plt.legend()
plt.show()
plt.hist( hr_data['Income'], bins = 10, color = 'red', alpha = 0.5, label = 'alpha = 0.5' )
plt.legend()
plt.show()
plt.hist( hr_data['Income'], bins = 10, color = 'red', alpha = 0.6, label = 'alpha = 0.6' )
plt.legend()
plt.show()
plt.hist( hr_data['Income'], bins = 10, color = 'red', alpha = 0.7, label = 'alpha = 0.7' )
plt.legend()
plt.show()
plt.hist( hr_data['Income'], bins = 10, color = 'red', alpha = 0.8, label = 'alpha = 0.8' )
plt.legend()
plt.show()
